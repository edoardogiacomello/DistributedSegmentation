# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
binary_or_multiclass = 'bin'
template = 'blob'
unbalanced_class = 'c2'
data =pd.read_csv('results/{}_{}_balanced_vs_unbalanced_{}.csv'.format(binary_or_multiclass, template, unbalanced_class), index_col=0)
metric_to_show = 'weighted avg_f1-score'
mu1=0.4
mu2=0.6
data = data.loc[data.mu_1_unbalanced == mu1]
data = data.loc[data.mu_2_unbalanced == mu2]
data['meta_method'] = 'mean'
data.loc[data['method']=='Majority Voting','meta_method'] = 'voting'
data.loc[data['method']=='Maximum Proposal','meta_method'] = 'max'
data.loc[data['method'].str.contains("Negotiation"),'meta_method'] = 'negotiation'
data.loc[data['method'].str.contains("Weighted"),'meta_method'] = 'weighted'
sb.set_style('darkgrid')
sb.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
sb.set_palette(sb.color_palette('Paired',11))
g = sb.relplot(data=data, row='std', col='unbalanced_agents',hue='method', style='meta_method', x = 'mu_balanced', y = metric_to_show, 
               style_order = ['negotiation','max','weighted','mean','voting'], ci=None, kind='line',
               markers = True)

# %%
binary_or_multiclass = 'bin'
template = 'chk'
unbalanced_class = 'c2'
data =pd.read_csv('results/{}_{}_balanced_vs_unbalanced_{}.csv'.format(binary_or_multiclass, template, unbalanced_class), index_col=0)
metric_to_show = 'weighted avg_f1-score'
mu1=0.4
mu2=0.6
data = data.loc[data.mu_1_unbalanced == mu1]
data = data.loc[data.mu_2_unbalanced == mu2]
data['meta_method'] = 'mean'
data.loc[data['method']=='Majority Voting','meta_method'] = 'voting'
data.loc[data['method']=='Maximum Proposal','meta_method'] = 'max'
data.loc[data['method'].str.contains("Negotiation"),'meta_method'] = 'negotiation'
data.loc[data['method'].str.contains("Weighted"),'meta_method'] = 'weighted'
sb.set_style('darkgrid')
sb.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
sb.set_palette(sb.color_palette('Paired',11))
g = sb.relplot(data=data, row='std', col='unbalanced_agents',hue='method', style='meta_method', x = 'mu_balanced', y = metric_to_show, 
               style_order = ['negotiation','max','weighted','mean','voting'], ci=None, kind='line',
               markers = True)

# %%
binary_or_multiclass = 'bin'
template = 'blob'
unbalanced_class = 'half'
data =pd.read_csv('results/{}_{}_balanced_vs_unbalanced_{}.csv'.format(binary_or_multiclass, template, unbalanced_class), index_col=0)
metric_to_show = 'weighted avg_f1-score'
mu1=0.4
mu2=0.4
data = data.loc[data.mu_1_unbalanced == mu1]
data = data.loc[data.mu_2_unbalanced == mu2]
data['meta_method'] = 'mean'
data.loc[data['method']=='Majority Voting','meta_method'] = 'voting'
data.loc[data['method']=='Maximum Proposal','meta_method'] = 'max'
data.loc[data['method'].str.contains("Negotiation"),'meta_method'] = 'negotiation'
data.loc[data['method'].str.contains("Weighted"),'meta_method'] = 'weighted'
sb.set_style('darkgrid')
sb.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
sb.set_palette(sb.color_palette('Paired',11))
g = sb.relplot(data=data, row='std', col='unbalanced_agents',hue='method', style='meta_method', x = 'mu_balanced', y = metric_to_show, 
               style_order = ['negotiation','max','weighted','mean','voting'], ci=None, kind='line',
               markers = True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-41-f52e3073fec6> in <module>
#      18 g = sb.relplot(data=data, row='std', col='unbalanced_agents',hue='method', style='meta_method', x = 'mu_balanced', y = metric_to_show,
#      19                style_order = ['negotiation','max','weighted','mean','voting'], ci=None, kind='line',
# ---> 20                markers = True)
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#    1611     g.map_dataframe(func, x, y,
#    1612                     hue=hue, size=size, style=style,
# -> 1613                     **plot_kws)
#    1614
#    1615     # Show the legend
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     821
#     822         # Finalize the annotations and layout
# --> 823         self._finalize_grid(args[:2])
#     824
#     825         return self
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in _finalize_grid(self, axlabels)
#     844     def _finalize_grid(self, axlabels):
#     845         """Finalize the annotations and layout."""
# --> 846         self.set_axis_labels(*axlabels)
#     847         self.set_titles()
#     848         self.fig.tight_layout()
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in set_axis_labels(self, x_var, y_var)
#     870         if x_var is not None:
#     871             self._x_var = x_var
# --> 872             self.set_xlabels(x_var)
#     873         if y_var is not None:
#     874             self._y_var = y_var
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in set_xlabels(self, label, **kwargs)
#     880         if label is None:
#     881             label = self._x_var
# --> 882         for ax in self._bottom_axes:
#     883             ax.set_xlabel(label, **kwargs)
#     884         return self
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in _bottom_axes(self)
#    1050         """Return a flat array of the bottom row of axes."""
#    1051         if self._col_wrap is None:
# -> 1052             return self.axes[-1, :].flat
#    1053         else:
#    1054             axes = []
#
# IndexError: index -1 is out of bounds for axis 0 with size 0

# %%
binary_or_multiclass = 'bin'
template = 'chk'
unbalanced_class = 'half'
data =pd.read_csv('results/{}_{}_balanced_vs_unbalanced_{}.csv'.format(binary_or_multiclass, template, unbalanced_class), index_col=0)
metric_to_show = 'weighted avg_f1-score'
mu1=0.4
mu2=0.6
data = data.loc[data.mu_1_unbalanced == mu1]
data = data.loc[data.mu_2_unbalanced == mu2]
data['meta_method'] = 'mean'
data.loc[data['method']=='Majority Voting','meta_method'] = 'voting'
data.loc[data['method']=='Maximum Proposal','meta_method'] = 'max'
data.loc[data['method'].str.contains("Negotiation"),'meta_method'] = 'negotiation'
data.loc[data['method'].str.contains("Weighted"),'meta_method'] = 'weighted'
sb.set_style('darkgrid')
sb.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
sb.set_palette(sb.color_palette('Paired',11))
g = sb.relplot(data=data, row='std', col='unbalanced_agents',hue='method', style='meta_method', x = 'mu_balanced', y = metric_to_show, 
               style_order = ['negotiation','max','weighted','mean','voting'], ci=None, kind='line',
               markers = True)
