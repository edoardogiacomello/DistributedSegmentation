# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import glob
import imageio

# %%
csv_samples = pd.DataFrame()
for csv_path in glob.glob('results/bcdh/csv/*.csv'):
    sample_id = os.path.basename(csv_path).split('.')[0]
    sample_csv = pd.read_csv(csv_path, index_col=0)
    sample_csv['sample'] = csv_path
    csv_samples = csv_samples.append(sample_csv)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
csv_samples.to_csv('results/bcdh/all_samples.csv')

# %%
means
# Out:
#                                                  accuracy  bird_f1-score  \
# method
# Majority Voting                                  0.601078   3.371348e-07
# Maximum Proposal                                 0.430575   0.000000e+00
# Mean Proposal                                    0.647254   0.000000e+00
# Negotiation - 3x3 Conv Entropy                   0.498883   0.000000e+00
# Negotiation - 3x3 Conv Entropy (Mean-Weighted)   0.508528   0.000000e+00
# Negotiation - 3x3 Conv Entropy (Weighted)        0.488149   0.000000e+00
# Negotiation - 5x5 Conv Entropy                   0.500315   0.000000e+00
# Negotiation - 5x5 Conv Entropy (Mean-Weighted)   0.509568   0.000000e+00
# Negotiation - 5x5 Conv Entropy (Weighted)        0.489119   0.000000e+00
# Negotiation - Mean Entropy                       0.647960   0.000000e+00
# Negotiation - Mean Entropy (Mean-Weighted)       0.455148   0.000000e+00
# Negotiation - Mean Entropy (Weighted)            0.455148   0.000000e+00
# ...

# %%
means.columns
# Out:
# Index(['accuracy', 'bird_f1-score', 'bird_precision', 'bird_recall',
#        'bird_support', 'cat_f1-score', 'cat_precision', 'cat_recall',
#        'cat_support', 'dog_f1-score', 'dog_precision', 'dog_recall',
#        'dog_support', 'horse_f1-score', 'horse_precision', 'horse_recall',
#        'horse_support', 'macro avg_f1-score', 'macro avg_precision',
#        'macro avg_recall', 'macro avg_support', 'micro avg_f1-score',
#        'micro avg_precision', 'micro avg_recall', 'micro avg_support',
#        'non_consensus_px', 'other_f1-score', 'other_precision', 'other_recall',
#        'other_support', 'weighted avg_f1-score', 'weighted avg_precision',
#        'weighted avg_recall', 'weighted avg_support'],
#       dtype='object')

# %%
means.plot(y='cat_f1-score', kind='bar')

# %%
means.plot(y='dog_f1-score', kind='bar')

# %%
means.plot(y='dog_f1-score', kind='bar')
