# %%
import pandas as pd
import numpy as np
from NegotiationConfig import *
import seaborn as sb
import matplotlib.pyplot as plt
sb.set(rc={'figure.figsize':(16,9), 'figure.dpi':300})

# %%
# This contains data for each step performed
steps_data = pd.read_csv('results/run_2019-09-12 v-unreliable.csv', index_col=0)
steps_data['consensus_progress'] = 1. - steps_data['consensus_current']/steps_data['consensus_start']
#data = data[data['step']<=MAX_STEPS]

# %%
MAX_STEP_DF = steps_data['step'].max()
MAX_STEP_DF = 50
step_expanded = pd.DataFrame()
all_groups= list()


for g, group in steps_data.groupby(['sample', 'method', 'agent']):
    last_step = group['step'].max()
    last_step_row = group.loc[group['step']==last_step]
    #print('\r Processing sample {} of {}, agent {}'.format(group['sample'].max(), steps_data['sample'].max(), group['agent'].iloc[0]), end='')
    print('\r'+str(g), end='')
    replications = range(last_step+1, MAX_STEP_DF+1)
    if len(replications) > 0:
        filling = pd.concat([last_step_row]*len(replications), ignore_index=True)
        filling['step'] = replications
        filling['status'] = 'consensus'
        #step_expanded = pd.concat([step_expanded, group, filling], ignore_index=True)
        all_groups += [group, filling]
    else:
        all_groups += [group]
    
    #new_group = group.concat(last_step_row)
#     for step in :
#         last_step_row.loc[:,'step'] = step
#         last_step_row.loc[:,'status'] = 'consensus'
#         group = group.append(last_step_row, ignore_index=True, sort=False)
    #step_expanded = step_expanded.append(group, ignore_index=True, sort=False)
    #step_expanded.to_csv('results/results_visualization.csv')
# Out:
# (384, 'ep', 'ag_bird')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-63-d1745aad97ea> in <module>
#      12     replications = range(last_step+1, MAX_STEP_DF+1)
#      13     if len(replications) > 0:
# ---> 14         filling = pd.concat([last_step_row]*len(replications), ignore_index=True)
#      15         filling['step'] = replications
#      16         filling['status'] = 'consensus'
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     227                        verify_integrity=verify_integrity,
#     228                        copy=copy, sort=sort)
# --> 229     return op.get_result()
#     230
#     231
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/reshape/concat.py in get_result(self)
#     424             new_data = concatenate_block_managers(
#     425                 mgrs_indexers, self.new_axes, concat_axis=self.axis,
# --> 426                 copy=self.copy)
#     427             if not self.copy:
#     428                 new_data._consolidate_inplace()
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals/managers.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    2059         else:
#    2060             b = make_block(
# -> 2061                 concatenate_join_units(join_units, concat_axis, copy=copy),
#    2062                 placement=placement)
#    2063         blocks.append(b)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals/concat.py in concatenate_join_units(join_units, concat_axis, copy)
#     240     to_concat = [ju.get_reindexed_values(empty_dtype=empty_dtype,
#     241                                          upcasted_na=upcasted_na)
# --> 242                  for ju in join_units]
#     243
#     244     if len(to_concat) == 1:
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals/concat.py in <listcomp>(.0)
#     240     to_concat = [ju.get_reindexed_values(empty_dtype=empty_dtype,
#     241                                          upcasted_na=upcasted_na)
# --> 242                  for ju in join_units]
#     243
#     244     if len(to_concat) == 1:
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals/concat.py in get_reindexed_values(self, empty_dtype, upcasted_na)
#     223             for ax, indexer in self.indexers.items():
#     224                 values = algos.take_nd(values, indexer, axis=ax,
# --> 225                                        fill_value=fill_value)
#     226
#     227         return values
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/algorithms.py in take_nd(arr, indexer, axis, out, fill_value, mask_info, allow_fill)
#    1647             # (s.t. df.values is c-contiguous and df._data.blocks[0] is its
#    1648             # f-contiguous transpose)
# -> 1649             out = np.empty(out_shape, dtype=dtype, order='F')
#    1650         else:
#    1651             out = np.empty(out_shape, dtype=dtype)
#
# KeyboardInterrupt:

# %%
only_last['sample'].max()
# Out:
# 1559

# %%
#sb.distplot(only_last['step'])
g = sb.FacetGrid(only_last, hue='method', col='method')
g.map(sb.distplot, "step", kde_kws={"shade": True})

# %%
#sb.distplot(only_last['step'])
g = sb.FacetGrid(only_last[only_last['step']<=50], hue='method', col='method')
g.map(sb.distplot, "step", kde_kws={"shade": True})

# %%
only_last[only_last['step']>=50]
# Out:
#        sample                                          png_path  \
# 3240      271  datasets/coco_animals/train/png/000000243309.png
# 3241      271  datasets/coco_animals/train/png/000000243309.png
# 3242      271  datasets/coco_animals/train/png/000000243309.png
# 3243      271  datasets/coco_animals/train/png/000000243309.png
# 6063   datasets/coco_animals/train/seg/000000077325.png     ei    55
# 6300   datasets/coco_animals/train/seg/000000307649.png     ei    61
# 6301   datasets/coco_animals/train/seg/000000307649.png     ei    61
# 6302   datasets/coco_animals/train/seg/000000307649.png     ei    61
# 6303   datasets/coco_animals/train/seg/000000307649.png     ei    61
# 8232   datasets/coco_animals/train/seg/000000374832.png     ei    53
# 8233   datasets/coco_animals/train/seg/000000374832.png     ei    53
# 8234   datasets/coco_animals/train/seg/000000374832.png     ei    53
# 8235   datasets/coco_animals/train/seg/000000374832.png     ei    53
# 10188  datasets/coco_animals/train/seg/000000011080.png     ei   499
# 10189  datasets/coco_animals/train/seg/000000011080.png     ei   499
# 10190  datasets/coco_animals/train/seg/000000011080.png     ei   499
# 10191  datasets/coco_animals/train/seg/000000011080.png     ei   499
# 10272  datasets/coco_animals/train/seg/000000196839.png     ei   499
# 10273  datasets/coco_animals/train/seg/000000196839.png     ei   499
# 10274  datasets/coco_animals/train/seg/000000196839.png     ei   499
# 10275  datasets/coco_animals/train/seg/000000196839.png     ei   499
# 13164  datasets/coco_animals/train/seg/000000237303.png     ei    53
# 13165  datasets/coco_animals/train/seg/000000237303.png     ei    53
# 13166  datasets/coco_animals/train/seg/000000237303.png     ei    53
# 13167  datasets/coco_animals/train/seg/000000237303.png     ei    53
# 13236  datasets/coco_animals/train/seg/000000269538.png     ei    66
# 13237  datasets/coco_animals/train/seg/000000269538.png     ei    66
# 13238  datasets/coco_animals/train/seg/000000269538.png     ei    66
# 13239  datasets/coco_animals/train/seg/000000269538.png     ei    66
# 13968  datasets/coco_animals/train/seg/000000043780.png     ei    57
# 13969  datasets/coco_animals/train/seg/000000043780.png     ei    57
# 13970  datasets/coco_animals/train/seg/000000043780.png     ei    57
# 13971  datasets/coco_animals/train/seg/000000043780.png     ei    57
# 16224  datasets/coco_animals/train/seg/000000225330.png     ei    51
# 16225  datasets/coco_animals/train/seg/000000225330.png     ei    51
# 16226  datasets/coco_animals/train/seg/000000225330.png     ei    51
# 16227  datasets/coco_animals/train/seg/000000225330.png     ei    51
# 18288  datasets/coco_animals/train/seg/000000195815.png     ei    51
# 18289  datasets/coco_animals/train/seg/000000195815.png     ei    51
# 18290  datasets/coco_animals/train/seg/000000195815.png     ei    51
# 18291  datasets/coco_animals/train/seg/000000195815.png     ei    51
#
#           agent       status  consensus_start  consensus_current  \
# 3240    ag_bird  negotiation             4962                  1
# 3241     ag_cat  negotiation             4962                  1
# 3242     ag_dog  negotiation             4962                  1
# 3243   ag_horse  negotiation             4962                  1
# 3828    ag_bird  negotiation             1715                  1
# 3829     ag_cat  negotiation             1715                  1
# 3830     ag_dog  negotiation             1715                  1
# 3831   ag_horse  negotiation             1715                  1
# 6060    ag_bird  negotiation             3119                  1
# 6061     ag_cat  negotiation             3119                  1
# 6062     ag_dog  negotiation             3119                  1
# 6063   ag_horse  negotiation             3119                  1
# 6300    ag_bird  negotiation             3590                  1
# 6301     ag_cat  negotiation             3590                  1
# 6302     ag_dog  negotiation             3590                  1
# 6303   ag_horse  negotiation             3590                  1
# 8232    ag_bird  negotiation            10484                  1
# 8233     ag_cat  negotiation            10484                  1
# 8234     ag_dog  negotiation            10484                  1
# 10190            0.999952
# 10191            0.999952
# 10272            0.999845
# 10273            0.999845
# 10274            0.999845
# 10275            0.999845
# 13164            0.998724
# 13165            0.998724
# 13166            0.998724
# 13167            0.998724
# 13236            0.999646
# 13237            0.999646
# 13238            0.999646
# 13239            0.999646
# 13968            0.999680
# 13969            0.999680
# 13970            0.999680
# 13971            0.999680
# 16224            0.999791
# 16225            0.999791
# 16226            0.999791
# 16227            0.999791
# 18288            0.999912
# 18289            0.999912
# 18290            0.999912
# 18291            0.999912
#
# [48 rows x 32 columns]

# %%
# Convergence speed
MAX_STEPS=50
sb.lineplot(data=steps_data[steps_data['step']<=MAX_STEPS], x='step', y='consensus_progress', hue='method')

# %%
sb.lineplot(data=steps_data[steps_data['step']<=MAX_STEPS], x='step', y='d_agr_gt_DSC', hue='method')

# %%
# Quality of the agreement wrt the ground truth
sb.barplot(data=only_last, x=step, y='' x='method', y='d_agr_gt_DSC')
for method in only_last['method'].unique():
    print('{}: {}'.format(method, only_last[only_last['method']==method]['d_agr_gt_DSC'].mean()))
# Out:
# ei: 0.9255032826658501
# ep: 0.9284997808996032
# v: 0.9223095934659165

# %%
# Quality of majority voting
sb.barplot(data=only_last, y='d_mv_gt_DSC')
only_last['d_mv_gt_DSC'].mean()
# Out:
# 0.9212462248418303

# %%
# Progress of Relative Performance vs Majority voting (1.0 performance)
#sb.violinplot(x='agent', y='step', hue='method', data=data)
sb.barplot(data=only_last, x='method', y='AGR_vs_MV DSC')

# %%
#Distance from each agent propsal to the agreement at the end of the negotiation. First (Dice Score), only account for majoritary label proposed by each agent. The second (MAE) accounts even for the agent uncertainty.
import matplotlib.pyplot as plt
#f, (ax1, ax2) = plt.subplots(2, 1, figsize=(7, 5), sharex=True)
plt.figure(figsize=(12, 4))
sb.barplot(data=only_last, x='method', y='d_prop_agr_DSC', hue='agent')
plt.figure(figsize=(12, 4))
sb.barplot(data=only_last, x='method', y='d_prop_agr_MAE', hue='agent')

# %%
#Distance from each agent propsal to the agreement for each step. First (Dice Score), only account for majoritary label proposed by each agent. The second (MSE) accounts even for the agent uncertainty.
import matplotlib.pyplot as plt
#f, (ax1, ax2) = plt.subplots(2, 1, figsize=(7, 5), sharex=True)
STEP_LIMIT=20
plt.figure(figsize=(12, 4))
sb.relplot(data=steps_data[steps_data['step']<=STEP_LIMIT], x='step', y='d_prop_agr_DSC', kind='line', hue='agent', style='agent', col='method', facet_kws={'sharey':'row'})
plt.figure(figsize=(12, 4))
sb.relplot(data=steps_data[steps_data['step']<=STEP_LIMIT], x='step', y='d_prop_agr_MAE', kind='line', hue='agent', style='agent', col='method', facet_kws={'sharey':'row'})

# %% [markdown]
# ## Test performances

# %%
model_perf = pd.read_csv('results/model_ep1_test_performances.csv', index_col='model_label')

# %%
agreement_perf = pd.DataFrame()
for (method, agent_name), group in only_last.groupby(['method', 'agent']):
    break
    #agreement_perf = agreement_perf.appen()

# %%
group['d_agr_gt_DSC'].mean()
# Out:
# 0.9255032826658504

# %%
model_perf
# Out:
#              dice_score       mae  dice_score_z     mae_z
# model_label
# bird           0.913127  0.056573      0.593294 -0.534424
# cat            0.918943  0.049520      0.726249 -0.846117
# dog            0.904710  0.061402      0.400881 -0.321048
# horse          0.811915  0.107170     -1.720424  1.701589

# %%
g
# Out:
# ('ei', 'ag_bird')
